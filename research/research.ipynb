# %%
example = {"key1": "value1", "key2": "value2" , "key3": "value3"}

# %%
from box import ConfigBox

# %%
example = ConfigBox({"key1": "value1", "key2": "value2" , "key3": "value3"})

# %%
example.key1
# Out:
# 'value1'

# %%
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(2, 3)
# Out:
# 6

# %%
get_product(2,"zczj")
# Out:
# 'zczjzczj'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(2, "5")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_product(2, "5")
#
# File d:\MLOPS\Projects\DataScienceProject1\myvenv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002425E590720> does not match annotation type <class 'int'>
